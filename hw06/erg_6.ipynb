# %% [markdown]
# <a href="https://colab.research.google.com/github/theoVasilas/Pattern_Recognition_weeklies/blob/main/hw06/erg_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import pandas as pd
import numpy as np

iris = datasets.load_iris() #Importing data set 
iris.keys()

iris = pd.DataFrame(
    data= np.c_[iris['data'], iris['target']],
    columns= iris['feature_names'] + ['target']
    )

species = []

for i in range(len(iris['target'])):
    if iris['target'][i] == 0:
        species.append("setosa")
    elif iris['target'][i] == 1:
        species.append('versicolor')
    else:
        species.append('virginica')


iris['species'] = species

# %%
import matplotlib.pyplot as plt

setosa = iris[iris.species == "setosa"]
versicolor = iris[iris.species=='versicolor']
virginica = iris[iris.species=='virginica']

fig, ax = plt.subplots()
fig.set_size_inches(13, 7) # adjusting the length and width of plot

# lables and scatter points
ax.scatter(setosa['petal length (cm)'], setosa['petal width (cm)'], label="Setosa", facecolor="blue")
ax.scatter(versicolor['petal length (cm)'], versicolor['petal width (cm)'], label="Versicolor", facecolor="yellow")
ax.scatter(virginica['petal length (cm)'], virginica['petal width (cm)'], label="Virginica", facecolor="red")


ax.set_xlabel("petal length (cm)")
ax.set_ylabel("petal width (cm)")
ax.grid()
ax.set_title("Iris petals")
ax.legend()

iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# remuving unuseful columns
#
# spliting to train data 80% and test data 20% with random selection
#
# scaling data with 0 mean remaning the standar diviation
#
# tranforming to tensorflow

# %%
from sklearn.model_selection import train_test_split
import torch
from sklearn.preprocessing import StandardScaler

# Droping the target and species since we only need the measurements
X = iris.drop(['target','species'], axis=1)

# converting into numpy array and assigning petal length and petal width
X = X.to_numpy()
y = iris['target'].to_numpy()

# Splitting into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.transform(X_test)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

print("Length of the test data : ", X_train.shape )
print("Length of the validation data : ", X_test.shape)
# Out:
# Length of the test data :  torch.Size([120, 4])
# Length of the validation data :  torch.Size([30, 4])

# %%
import torch.nn as nn

class NN_Sigmoid(nn.Module):
    def __init__(self):
        super(NN_Sigmoid, self).__init__()
        #self.flatten = nn.Flatten()
        self.linear_stack = nn.Sequential(
            nn.Linear(4, 30),
            nn.Sigmoid(),
            nn.Linear(30,3),
        )

    def forward(self, x):
        #x = self.flatten(x)
        logits = self.linear_stack(x)
        return logits

class NN_ReLU(nn.Module):
    def __init__(self):
        super(NN_ReLU, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_stack = nn.Sequential(
            nn.Linear(4, 30),
            nn.ReLU(),
            nn.Linear(30,3),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_stack(x)
        return logits

class My_NN_Relu(nn.Module):
    def __init__(self):
        super(My_NN_Relu, self).__init__()
        #self.flatten = nn.Flatten()
        self.linear_stack = nn.Sequential(
            nn.Linear(4, 20),
            nn.ReLU(),
            nn.Linear(20,10),
            nn.ReLU(),
            nn.Linear(10,3),
        )

        # Define proportion or neurons to dropout
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        #x = self.flatten(x)
        logits = self.linear_stack(x)
        logits = self.dropout(logits)
        return logits

models = [ NN_Sigmoid() , NN_ReLU() , My_NN_Relu() ]
torch.save(models, 'models.pth')

# %% [markdown]
# Create a trainuing loop

# %%
def train_loop(model,optimizer,path_weigths,criterion,schedule,X_train,y_train,X_test,y_test,num_epochs,train_losses,test_losses):
    loss_train_old = 100
    for epoch in range(num_epochs):
        #clear out the gradients from the last step loss.backward()
        optimizer.zero_grad()

        # Compute prediction and loss
        #forward feed
        output_train = model(X_train)
        #calculate the loss
        loss_train = loss_fn(output_train, y_train)

        #backward propagation: calculate gradients
        loss_train.backward()
        #update the weights
        optimizer.step()

        #calculate train loss without optimizing model weights
        output_test = model(X_test)
        loss_test = criterion(output_test,y_test)

        train_losses[epoch] = loss_train.item()
        test_losses[epoch] = loss_test.item()
        correct_test = (output_test.argmax(1) == y_test).type(torch.float).sum().item()
            
        
        if (epoch + 1) % 50 == 0:
            print(f" Epoch {epoch+1}/{num_epochs}, Train Loss: {loss_train.item():.4f}, Test Loss: {loss_test.item():.4f}")
            correct_test /= len(X_test)
            print(f"Accuracy: {(100*correct_test):>0.1f}% \n")
        
        #save the best model weights if the train loss has decresed
        if train_losses[epoch] < loss_train_old :
          torch.save(model.state_dict(), path_weigths)
          loss_train_old = train_losses[epoch]
          print("saved ",end=" ")

    if schedule == 1 :
      #decreseng learning rate      
      scheduler.step()      


    print(f"Weights data have been saved in {(path_weigths)} \n")

# %%
def print_the_model(model):
  #print the model
  print(model)
  params = list(model.parameters())
  print("Number of learnable parameters' sets: " , len(params))
  for i in params:
    print(i.size()) 

model_selc = 2 ; #0:Sigmoid30 1:Relu30 2:MyNN
model = models[model_selc] ;

print_the_model(model)
# Out:
# My_NN_Relu(
#   (linear_stack): Sequential(
#     (0): Linear(in_features=4, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=3, bias=True)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Number of learnable parameters' sets:  6
# torch.Size([20, 4])
# torch.Size([20])
# torch.Size([10, 20])
# torch.Size([10])
# torch.Size([3, 10])
# torch.Size([3])

# %%
#number o iterations
num_epochs = 10000
train_losses = np.zeros(num_epochs)
test_losses  = np.zeros(num_epochs)

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

schedule_en = 1 #true=1 false=0

if schedule_en==1:
  #step each time
  learning_rate = 0.01
else:
  learning_rate = 0.001

optimizer_SGD = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=0.9)
optimizer_Adam = torch.optim.Adam(model.parameters(),lr=learning_rate)
optimizer_Adam_2 = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.05)
optimizers = [ optimizer_SGD , optimizer_Adam , optimizer_Adam_2 ]

path_weigths = ["best_weights_SGD.pth" , "best_weights_Adam.pth" , "best_weights_Adam_2.pth" ]

i = 0  # 0,1,2
PATH = path_weigths[i]
optimizer = optimizers[i]

#Decays the learning rate of each parameter group by gamma every epoch.
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# start training 
train_loop(model,optimizer,PATH,loss_fn,schedule_en,X_train,y_train,X_test,y_test,num_epochs,train_losses,test_losses)

plt.figure(figsize=(10,10))
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()
# Out:
# saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved   Epoch 50/10000, Train Loss: 0.5334, Test Loss: 0.6874
# Accuracy: 53.3%
#
# saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved  saved   Epoch 100/10000, Train Loss: 0.2484, Test Loss: 0.3577
# Accuracy: 83.3%
#
# saved  saved  saved  saved  saved  saved  saved  saved  saved   Epoch 150/10000, Train Loss: 0.1731, Test Loss: 0.2672
# Accuracy: 90.0%
#
# saved  saved  saved  saved  saved  saved  saved   Epoch 200/10000, Train Loss: 0.1536, Test Loss: 0.1926
# Accuracy: 100.0%
#
# saved  saved   Epoch 250/10000, Train Loss: 0.1268, Test Loss: 0.1148
# Accuracy: 93.3%
#
# saved  saved   Epoch 300/10000, Train Loss: 0.1059, Test Loss: 0.1304
# Accuracy: 96.7%
#
# saved  saved   Epoch 350/10000, Train Loss: 0.1157, Test Loss: 0.1640
# Accuracy: 93.3%
#
# saved  saved  saved   Epoch 400/10000, Train Loss: 0.1179, Test Loss: 0.1654
# Accuracy: 90.0%
#
# saved   Epoch 450/10000, Train Loss: 0.1035, Test Loss: 0.1434
# Accuracy: 90.0%
#
#  Epoch 500/10000, Train Loss: 0.0968, Test Loss: 0.1201
# Accuracy: 93.3%
#
#  Epoch 550/10000, Train Loss: 0.1052, Test Loss: 0.1121
# Accuracy: 93.3%
#
# saved  saved   Epoch 600/10000, Train Loss: 0.0712, Test Loss: 0.0831
# Accuracy: 96.7%
#
#  Epoch 650/10000, Train Loss: 0.1039, Test Loss: 0.0960
# Accuracy: 96.7%
#
# saved   Epoch 700/10000, Train Loss: 0.0932, Test Loss: 0.0991
# Accuracy: 96.7%
#
# saved   Epoch 750/10000, Train Loss: 0.0754, Test Loss: 0.0815
# Accuracy: 93.3%
#
#  Epoch 800/10000, Train Loss: 0.0861, Test Loss: 0.0800
# Accuracy: 96.7%
#
# saved   Epoch 850/10000, Train Loss: 0.0393, Test Loss: 0.2173
# Accuracy: 83.3%
#
#  Epoch 900/10000, Train Loss: 0.0693, Test Loss: 0.1183
# Accuracy: 96.7%
#
#  Epoch 950/10000, Train Loss: 0.0866, Test Loss: 0.1193
# Accuracy: 96.7%
#
#  Epoch 1000/10000, Train Loss: 0.0522, Test Loss: 0.1460
# Accuracy: 93.3%
#
#  Epoch 1050/10000, Train Loss: 0.0726, Test Loss: 0.1121
# Accuracy: 96.7%
#
#  Epoch 1100/10000, Train Loss: 0.0947, Test Loss: 0.0695
# Accuracy: 96.7%
#
#  Epoch 1150/10000, Train Loss: 0.0599, Test Loss: 0.1305
# Accuracy: 93.3%
#
# saved   Epoch 1200/10000, Train Loss: 0.0789, Test Loss: 0.0788
# Accuracy: 93.3%
#
# saved   Epoch 1250/10000, Train Loss: 0.0679, Test Loss: 0.1361
# Accuracy: 93.3%
#
#  Epoch 1300/10000, Train Loss: 0.0624, Test Loss: 0.1136
# Accuracy: 93.3%
#
#  Epoch 1350/10000, Train Loss: 0.0665, Test Loss: 0.0988
# Accuracy: 96.7%
#
#  Epoch 1400/10000, Train Loss: 0.0616, Test Loss: 0.0969
# Accuracy: 96.7%
#
#  Epoch 1450/10000, Train Loss: 0.0860, Test Loss: 0.1552
# Accuracy: 93.3%
#
#  Epoch 1500/10000, Train Loss: 0.0672, Test Loss: 0.1015
# Accuracy: 96.7%
#
#  Epoch 1550/10000, Train Loss: 0.0589, Test Loss: 0.0735
# Accuracy: 93.3%
#
#  Epoch 1600/10000, Train Loss: 0.0863, Test Loss: 0.1236
# Accuracy: 96.7%
#
#  Epoch 1650/10000, Train Loss: 0.0624, Test Loss: 0.0931
# Accuracy: 96.7%
#
#  Epoch 1700/10000, Train Loss: 0.0692, Test Loss: 0.1205
# Accuracy: 96.7%
#
#  Epoch 1750/10000, Train Loss: 0.0750, Test Loss: 0.0836
# Accuracy: 96.7%
#
#  Epoch 1800/10000, Train Loss: 0.0633, Test Loss: 0.1478
# Accuracy: 93.3%
#
#  Epoch 1850/10000, Train Loss: 0.0607, Test Loss: 0.1157
# Accuracy: 96.7%
#
#  Epoch 1900/10000, Train Loss: 0.0805, Test Loss: 0.0965
# Accuracy: 96.7%
#
#  Epoch 1950/10000, Train Loss: 0.0654, Test Loss: 0.1229
# Accuracy: 93.3%
#
#  Epoch 2000/10000, Train Loss: 0.0788, Test Loss: 0.0897
# Accuracy: 96.7%
#
#  Epoch 2050/10000, Train Loss: 0.0641, Test Loss: 0.0904
# Accuracy: 96.7%
#
#  Epoch 2100/10000, Train Loss: 0.0756, Test Loss: 0.1314
# Accuracy: 93.3%
#
#  Epoch 2150/10000, Train Loss: 0.0666, Test Loss: 0.0903
# Accuracy: 96.7%
#
#  Epoch 2200/10000, Train Loss: 0.0606, Test Loss: 0.0840
# Accuracy: 93.3%
#
#  Epoch 2250/10000, Train Loss: 0.0685, Test Loss: 0.0761
# Accuracy: 96.7%
#
#  Epoch 2300/10000, Train Loss: 0.0518, Test Loss: 0.0985
# Accuracy: 96.7%
#
#  Epoch 2350/10000, Train Loss: 0.0615, Test Loss: 0.1059
# Accuracy: 96.7%
#
#  Epoch 2400/10000, Train Loss: 0.0577, Test Loss: 0.1281
# Accuracy: 96.7%
#
#  Epoch 2450/10000, Train Loss: 0.0745, Test Loss: 0.0488
# Accuracy: 96.7%
#
#  Epoch 2500/10000, Train Loss: 0.0525, Test Loss: 0.1179
# Accuracy: 96.7%
#
#  Epoch 2550/10000, Train Loss: 0.0775, Test Loss: 0.0556
# Accuracy: 96.7%
#
# saved   Epoch 2600/10000, Train Loss: 0.0827, Test Loss: 0.0860
# Accuracy: 96.7%
#
#  Epoch 2650/10000, Train Loss: 0.0512, Test Loss: 0.1262
# Accuracy: 93.3%
#
#  Epoch 2700/10000, Train Loss: 0.0503, Test Loss: 0.1081
# Accuracy: 93.3%
#
#  Epoch 2750/10000, Train Loss: 0.0526, Test Loss: 0.1032
# Accuracy: 96.7%
#
#  Epoch 2800/10000, Train Loss: 0.0853, Test Loss: 0.0977
# Accuracy: 96.7%
#
#  Epoch 2850/10000, Train Loss: 0.0529, Test Loss: 0.1039
# Accuracy: 93.3%
#
#  Epoch 2900/10000, Train Loss: 0.0575, Test Loss: 0.1055
# Accuracy: 96.7%
#
#  Epoch 2950/10000, Train Loss: 0.0571, Test Loss: 0.1428
# Accuracy: 96.7%
#
#  Epoch 3000/10000, Train Loss: 0.0478, Test Loss: 0.1406
# Accuracy: 90.0%
#
#  Epoch 3050/10000, Train Loss: 0.0584, Test Loss: 0.0992
# Accuracy: 93.3%
#
#  Epoch 3100/10000, Train Loss: 0.0546, Test Loss: 0.1250
# Accuracy: 93.3%
#
#  Epoch 3150/10000, Train Loss: 0.0684, Test Loss: 0.0682
# Accuracy: 96.7%
#
#  Epoch 3200/10000, Train Loss: 0.0385, Test Loss: 0.1082
# Accuracy: 96.7%
#
#  Epoch 3250/10000, Train Loss: 0.0466, Test Loss: 0.0947
# Accuracy: 96.7%
#
#  Epoch 3300/10000, Train Loss: 0.0550, Test Loss: 0.0831
# Accuracy: 96.7%
#
#  Epoch 3350/10000, Train Loss: 0.0520, Test Loss: 0.1222
# Accuracy: 96.7%
#
#  Epoch 3400/10000, Train Loss: 0.0603, Test Loss: 0.1098
# Accuracy: 93.3%
#
#  Epoch 3450/10000, Train Loss: 0.0821, Test Loss: 0.1497
# Accuracy: 93.3%
#
#  Epoch 3500/10000, Train Loss: 0.0509, Test Loss: 0.0824
# Accuracy: 96.7%
#
#  Epoch 3550/10000, Train Loss: 0.0729, Test Loss: 0.1260
# Accuracy: 93.3%
#
#  Epoch 3600/10000, Train Loss: 0.0652, Test Loss: 0.1167
# Accuracy: 96.7%
#
#  Epoch 3650/10000, Train Loss: 0.0731, Test Loss: 0.1205
# Accuracy: 96.7%
#
#  Epoch 3700/10000, Train Loss: 0.0726, Test Loss: 0.1753
# Accuracy: 93.3%
#
#  Epoch 3750/10000, Train Loss: 0.0481, Test Loss: 0.1069
# Accuracy: 96.7%
#
#  Epoch 3800/10000, Train Loss: 0.0615, Test Loss: 0.1429
# Accuracy: 96.7%
#
#  Epoch 3850/10000, Train Loss: 0.0701, Test Loss: 0.1213
# Accuracy: 96.7%
#
# saved   Epoch 3900/10000, Train Loss: 0.0790, Test Loss: 0.1324
# Accuracy: 96.7%
#
#  Epoch 3950/10000, Train Loss: 0.0488, Test Loss: 0.0935
# Accuracy: 96.7%
#
#  Epoch 4000/10000, Train Loss: 0.0603, Test Loss: 0.0804
# Accuracy: 96.7%
#
#  Epoch 4050/10000, Train Loss: 0.0756, Test Loss: 0.0756
# Accuracy: 96.7%
#
#  Epoch 4100/10000, Train Loss: 0.0526, Test Loss: 0.1388
# Accuracy: 96.7%
#
#  Epoch 4150/10000, Train Loss: 0.0526, Test Loss: 0.1203
# Accuracy: 96.7%
#
#  Epoch 4200/10000, Train Loss: 0.0595, Test Loss: 0.0683
# Accuracy: 96.7%
#
# saved   Epoch 4250/10000, Train Loss: 0.0692, Test Loss: 0.1192
# Accuracy: 96.7%
#
#  Epoch 4300/10000, Train Loss: 0.0524, Test Loss: 0.0950
# Accuracy: 96.7%
#
#  Epoch 4350/10000, Train Loss: 0.0617, Test Loss: 0.0971
# Accuracy: 96.7%
#
#  Epoch 4400/10000, Train Loss: 0.0550, Test Loss: 0.0452
# Accuracy: 100.0%
#
#  Epoch 4450/10000, Train Loss: 0.0530, Test Loss: 0.0903
# Accuracy: 96.7%
#
#  Epoch 4500/10000, Train Loss: 0.0621, Test Loss: 0.1074
# Accuracy: 90.0%
#
#  Epoch 4550/10000, Train Loss: 0.0614, Test Loss: 0.1113
# Accuracy: 93.3%
#
#  Epoch 4600/10000, Train Loss: 0.0667, Test Loss: 0.1257
# Accuracy: 93.3%
#
#  Epoch 4650/10000, Train Loss: 0.0554, Test Loss: 0.1264
# Accuracy: 96.7%
#
#  Epoch 4700/10000, Train Loss: 0.0594, Test Loss: 0.0863
# Accuracy: 93.3%
#
#  Epoch 4750/10000, Train Loss: 0.0707, Test Loss: 0.0652
# Accuracy: 96.7%
#
#  Epoch 4800/10000, Train Loss: 0.0701, Test Loss: 0.1014
# Accuracy: 93.3%
#
#  Epoch 4850/10000, Train Loss: 0.0688, Test Loss: 0.1059
# Accuracy: 93.3%
#
#  Epoch 4900/10000, Train Loss: 0.0660, Test Loss: 0.1665
# Accuracy: 93.3%
#
#  Epoch 4950/10000, Train Loss: 0.0639, Test Loss: 0.0975
# Accuracy: 93.3%
#
#  Epoch 5000/10000, Train Loss: 0.0613, Test Loss: 0.0920
# Accuracy: 93.3%
#
#  Epoch 5050/10000, Train Loss: 0.0745, Test Loss: 0.1427
# Accuracy: 96.7%
#
#  Epoch 5100/10000, Train Loss: 0.0496, Test Loss: 0.1170
# Accuracy: 96.7%
#
#  Epoch 5150/10000, Train Loss: 0.0643, Test Loss: 0.1783
# Accuracy: 93.3%
#
#  Epoch 5200/10000, Train Loss: 0.0569, Test Loss: 0.1356
# Accuracy: 93.3%
#
#  Epoch 5250/10000, Train Loss: 0.0742, Test Loss: 0.0994
# Accuracy: 93.3%
#
#  Epoch 5300/10000, Train Loss: 0.0518, Test Loss: 0.1530
# Accuracy: 96.7%
#
#  Epoch 5350/10000, Train Loss: 0.0426, Test Loss: 0.1312
# Accuracy: 96.7%
#
#  Epoch 5400/10000, Train Loss: 0.0598, Test Loss: 0.0993
# Accuracy: 93.3%
#
#  Epoch 5450/10000, Train Loss: 0.0556, Test Loss: 0.1250
# Accuracy: 96.7%
#
#  Epoch 5500/10000, Train Loss: 0.0664, Test Loss: 0.1091
# Accuracy: 96.7%
#
#  Epoch 5550/10000, Train Loss: 0.0873, Test Loss: 0.0815
# Accuracy: 93.3%
#
#  Epoch 5600/10000, Train Loss: 0.0479, Test Loss: 0.0791
# Accuracy: 96.7%
#
#  Epoch 5650/10000, Train Loss: 0.0418, Test Loss: 0.1316
# Accuracy: 93.3%
#
#  Epoch 5700/10000, Train Loss: 0.0448, Test Loss: 0.1557
# Accuracy: 90.0%
#
#  Epoch 5750/10000, Train Loss: 0.0433, Test Loss: 0.1385
# Accuracy: 96.7%
#
#  Epoch 5800/10000, Train Loss: 0.0604, Test Loss: 0.1198
# Accuracy: 93.3%
#
#  Epoch 5850/10000, Train Loss: 0.0706, Test Loss: 0.1025
# Accuracy: 96.7%
#
#  Epoch 5900/10000, Train Loss: 0.0575, Test Loss: 0.1243
# Accuracy: 96.7%
#
#  Epoch 5950/10000, Train Loss: 0.0514, Test Loss: 0.1309
# Accuracy: 96.7%
#
#  Epoch 6000/10000, Train Loss: 0.0588, Test Loss: 0.1607
# Accuracy: 96.7%
#
#  Epoch 6050/10000, Train Loss: 0.0473, Test Loss: 0.1250
# Accuracy: 90.0%
#
#  Epoch 6100/10000, Train Loss: 0.0551, Test Loss: 0.1280
# Accuracy: 93.3%
#
#  Epoch 6150/10000, Train Loss: 0.0472, Test Loss: 0.1052
# Accuracy: 93.3%
#
#  Epoch 6200/10000, Train Loss: 0.0411, Test Loss: 0.1042
# Accuracy: 93.3%
#
#  Epoch 6250/10000, Train Loss: 0.0441, Test Loss: 0.1291
# Accuracy: 93.3%
#
#  Epoch 6300/10000, Train Loss: 0.0501, Test Loss: 0.1178
# Accuracy: 96.7%
#
#  Epoch 6350/10000, Train Loss: 0.0536, Test Loss: 0.1509
# Accuracy: 96.7%
#
#  Epoch 6400/10000, Train Loss: 0.0669, Test Loss: 0.1328
# Accuracy: 93.3%
#
#  Epoch 6450/10000, Train Loss: 0.0511, Test Loss: 0.1625
# Accuracy: 93.3%
#
#  Epoch 6500/10000, Train Loss: 0.0384, Test Loss: 0.1784
# Accuracy: 93.3%
#
#  Epoch 6550/10000, Train Loss: 0.0590, Test Loss: 0.1895
# Accuracy: 93.3%
#
#  Epoch 6600/10000, Train Loss: 0.0625, Test Loss: 0.1285
# Accuracy: 96.7%
#
#  Epoch 6650/10000, Train Loss: 0.0671, Test Loss: 0.1469
# Accuracy: 96.7%
#
#  Epoch 6700/10000, Train Loss: 0.0523, Test Loss: 0.1326
# Accuracy: 96.7%
#
#  Epoch 6750/10000, Train Loss: 0.0539, Test Loss: 0.1124
# Accuracy: 93.3%
#
#  Epoch 6800/10000, Train Loss: 0.0526, Test Loss: 0.1409
# Accuracy: 93.3%
#
#  Epoch 6850/10000, Train Loss: 0.0611, Test Loss: 0.1446
# Accuracy: 93.3%
#
#  Epoch 6900/10000, Train Loss: 0.0506, Test Loss: 0.1262
# Accuracy: 96.7%
#
#  Epoch 6950/10000, Train Loss: 0.0496, Test Loss: 0.1354
# Accuracy: 90.0%
#
#  Epoch 7000/10000, Train Loss: 0.0542, Test Loss: 0.1510
# Accuracy: 93.3%
#
#  Epoch 7050/10000, Train Loss: 0.0545, Test Loss: 0.1540
# Accuracy: 93.3%
#
#  Epoch 7100/10000, Train Loss: 0.0512, Test Loss: 0.1299
# Accuracy: 96.7%
#
#  Epoch 7150/10000, Train Loss: 0.0762, Test Loss: 0.1354
# Accuracy: 96.7%
#
#  Epoch 7200/10000, Train Loss: 0.0503, Test Loss: 0.1139
# Accuracy: 93.3%
#
# saved   Epoch 7250/10000, Train Loss: 0.0509, Test Loss: 0.1550
# Accuracy: 90.0%
#
#  Epoch 7300/10000, Train Loss: 0.0512, Test Loss: 0.1223
# Accuracy: 93.3%
#
#  Epoch 7350/10000, Train Loss: 0.0561, Test Loss: 0.1103
# Accuracy: 93.3%
#
#  Epoch 7400/10000, Train Loss: 0.0552, Test Loss: 0.1855
# Accuracy: 96.7%
#
#  Epoch 7450/10000, Train Loss: 0.0640, Test Loss: 0.1581
# Accuracy: 96.7%
#
#  Epoch 7500/10000, Train Loss: 0.0617, Test Loss: 0.1583
# Accuracy: 90.0%
#
#  Epoch 7550/10000, Train Loss: 0.0679, Test Loss: 0.1240
# Accuracy: 96.7%
#
#  Epoch 7600/10000, Train Loss: 0.0694, Test Loss: 0.1345
# Accuracy: 93.3%
#
#  Epoch 7650/10000, Train Loss: 0.0548, Test Loss: 0.1224
# Accuracy: 93.3%
#
#  Epoch 7700/10000, Train Loss: 0.0479, Test Loss: 0.0674
# Accuracy: 96.7%
#
#  Epoch 7750/10000, Train Loss: 0.0556, Test Loss: 0.1048
# Accuracy: 96.7%
#
#  Epoch 7800/10000, Train Loss: 0.0516, Test Loss: 0.1240
# Accuracy: 96.7%
#
#  Epoch 7850/10000, Train Loss: 0.0622, Test Loss: 0.1435
# Accuracy: 96.7%
#
#  Epoch 7900/10000, Train Loss: 0.0631, Test Loss: 0.1114
# Accuracy: 93.3%
#
#  Epoch 7950/10000, Train Loss: 0.0505, Test Loss: 0.1169
# Accuracy: 93.3%
#
#  Epoch 8000/10000, Train Loss: 0.0755, Test Loss: 0.1513
# Accuracy: 90.0%
#
#  Epoch 8050/10000, Train Loss: 0.0447, Test Loss: 0.1459
# Accuracy: 96.7%
#
#  Epoch 8100/10000, Train Loss: 0.0545, Test Loss: 0.1128
# Accuracy: 93.3%
#
#  Epoch 8150/10000, Train Loss: 0.0477, Test Loss: 0.1124
# Accuracy: 93.3%
#
#  Epoch 8200/10000, Train Loss: 0.0530, Test Loss: 0.1084
# Accuracy: 93.3%
#
#  Epoch 8250/10000, Train Loss: 0.0453, Test Loss: 0.1851
# Accuracy: 96.7%
#
#  Epoch 8300/10000, Train Loss: 0.0603, Test Loss: 0.1590
# Accuracy: 96.7%
#
#  Epoch 8350/10000, Train Loss: 0.0659, Test Loss: 0.1238
# Accuracy: 96.7%
#
#  Epoch 8400/10000, Train Loss: 0.0583, Test Loss: 0.1507
# Accuracy: 93.3%
#
#  Epoch 8450/10000, Train Loss: 0.0512, Test Loss: 0.0971
# Accuracy: 90.0%
#
#  Epoch 8500/10000, Train Loss: 0.0655, Test Loss: 0.1768
# Accuracy: 93.3%
#
#  Epoch 8550/10000, Train Loss: 0.0486, Test Loss: 0.1117
# Accuracy: 93.3%
#
#  Epoch 8600/10000, Train Loss: 0.0605, Test Loss: 0.1285
# Accuracy: 93.3%
#
#  Epoch 8650/10000, Train Loss: 0.0538, Test Loss: 0.0907
# Accuracy: 93.3%
#
#  Epoch 8700/10000, Train Loss: 0.0516, Test Loss: 0.1194
# Accuracy: 93.3%
#
#  Epoch 8750/10000, Train Loss: 0.0535, Test Loss: 0.1359
# Accuracy: 93.3%
#
#  Epoch 8800/10000, Train Loss: 0.0543, Test Loss: 0.1266
# Accuracy: 93.3%
#
#  Epoch 8850/10000, Train Loss: 0.0873, Test Loss: 0.1157
# Accuracy: 93.3%
#
#  Epoch 8900/10000, Train Loss: 0.0400, Test Loss: 0.1398
# Accuracy: 96.7%
#
#  Epoch 8950/10000, Train Loss: 0.0705, Test Loss: 0.1159
# Accuracy: 93.3%
#
#  Epoch 9000/10000, Train Loss: 0.0588, Test Loss: 0.1502
# Accuracy: 93.3%
#
#  Epoch 9050/10000, Train Loss: 0.0569, Test Loss: 0.1235
# Accuracy: 93.3%
#
#  Epoch 9100/10000, Train Loss: 0.0598, Test Loss: 0.1409
# Accuracy: 93.3%
#
#  Epoch 9150/10000, Train Loss: 0.0499, Test Loss: 0.0920
# Accuracy: 96.7%
#
#  Epoch 9200/10000, Train Loss: 0.0550, Test Loss: 0.1236
# Accuracy: 96.7%
#
#  Epoch 9250/10000, Train Loss: 0.0896, Test Loss: 0.0875
# Accuracy: 93.3%
#
#  Epoch 9300/10000, Train Loss: 0.0490, Test Loss: 0.1208
# Accuracy: 86.7%
#
#  Epoch 9350/10000, Train Loss: 0.0413, Test Loss: 0.1617
# Accuracy: 90.0%
#
#  Epoch 9400/10000, Train Loss: 0.0533, Test Loss: 0.1181
# Accuracy: 93.3%
#
#  Epoch 9450/10000, Train Loss: 0.0617, Test Loss: 0.0872
# Accuracy: 96.7%
#
#  Epoch 9500/10000, Train Loss: 0.0655, Test Loss: 0.1178
# Accuracy: 96.7%
#
#  Epoch 9550/10000, Train Loss: 0.0583, Test Loss: 0.1204
# Accuracy: 93.3%
#
#  Epoch 9600/10000, Train Loss: 0.0494, Test Loss: 0.1325
# Accuracy: 93.3%
#
#  Epoch 9650/10000, Train Loss: 0.0581, Test Loss: 0.1000
# Accuracy: 96.7%
#
#  Epoch 9700/10000, Train Loss: 0.0626, Test Loss: 0.1627
# Accuracy: 93.3%
#
#  Epoch 9750/10000, Train Loss: 0.0449, Test Loss: 0.2134
# Accuracy: 90.0%
#
#  Epoch 9800/10000, Train Loss: 0.0542, Test Loss: 0.1419
# Accuracy: 96.7%
#
#  Epoch 9850/10000, Train Loss: 0.0509, Test Loss: 0.0921
# Accuracy: 96.7%
#
#  Epoch 9900/10000, Train Loss: 0.0585, Test Loss: 0.1319
# Accuracy: 96.7%
#
#  Epoch 9950/10000, Train Loss: 0.0523, Test Loss: 0.0758
# Accuracy: 96.7%
#
#  Epoch 10000/10000, Train Loss: 0.0537, Test Loss: 0.1638
# Accuracy: 96.7%
#
# Weights data have been saved in best_weights_SGD.pth

# %%
print(f"load weights from {(PATH)}\n")
print_the_model(model)
#model.load_state_dict(torch.load(PATH))
# Out:
# load weights from best_weights_SGD.pth
#
# My_NN_Relu(
#   (linear_stack): Sequential(
#     (0): Linear(in_features=4, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=3, bias=True)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Number of learnable parameters' sets:  6
# torch.Size([20, 4])
# torch.Size([20])
# torch.Size([10, 20])
# torch.Size([10])
# torch.Size([3, 10])
# torch.Size([3])

# %% [markdown]
# Confusion map for train

# %%
output_train = model(X_train)

from sklearn import metrics

print("Precision, Recall, Confusion matrix, in training\n")

# Precision Recall scores
print(metrics.classification_report(y_train, output_train.argmax(1) , digits=3))

# Confusion matrix
print(metrics.confusion_matrix(y_train, output_train.argmax(1) ))
# Out:
# Precision, Recall, Confusion matrix, in training
#
#               precision    recall  f1-score   support
#
#            0      0.977     1.000     0.988        42
#            1      0.971     0.917     0.943        36
#            2      0.953     0.976     0.965        42
#
#     accuracy                          0.967       120
#    macro avg      0.967     0.964     0.965       120
# weighted avg      0.967     0.967     0.966       120
#
# [[42  0  0]
#  [ 1 33  2]
#  [ 0  1 41]]

# %% [markdown]
# Confusion map for test

# %%
output_test = model(X_test)

from sklearn import metrics

print("Precision, Recall, Confusion matrix, in testing\n")

# Precision Recall scores
print(metrics.classification_report(y_test, output_test.argmax(1) , digits=3))

# Confusion matrix
print(metrics.confusion_matrix(y_test, output_test.argmax(1) ))
# Out:
# Precision, Recall, Confusion matrix, in testing
#
#               precision    recall  f1-score   support
#
#            0      0.889     1.000     0.941         8
#            1      1.000     0.857     0.923        14
#            2      0.889     1.000     0.941         8
#
#     accuracy                          0.933        30
#    macro avg      0.926     0.952     0.935        30
# weighted avg      0.941     0.933     0.933        30
#
# [[ 8  0  0]
#  [ 1 12  1]
#  [ 0  0  8]]
